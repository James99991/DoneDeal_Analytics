# %% [markdown]
# # Extracting Info from Ads
#
# `Author: James Smith`
#
# `Date: 22/12/2019`

# %% [markdown]
# Given an add link, we want to extract all information that we want from it
#
# - Phone Number - using workaround
# - All other info - using JSON dictionary located at bottom of page code
#
# Example Ad: https://www.donedeal.ie/cars-for-sale/very-clean-4x4/23802005

# %% [markdown]
# ## Function to get info from ad link

# %%
def get_info_from_ad_link(url):
    """
    Given a url it returns a dataframe of info
    """
    
    #----- Define custom functions -----#
    
    def find_char_index(s, ch):
        """
        Function to return indexes of a character in a given string
        https://stackoverflow.com/questions/11122291/how-to-find-char-in-string-and-get-all-the-indexes
        """
        return [i for i, ltr in enumerate(s) if ltr == ch]
    
    def get_phone_number(url):
        """
        Given a url this function return a dictionary containing 
        the sellers phone number.
        Returns None if an error occurs
        This happens due to frequent scraping - "Please contact customer support"
        """
        phone_headers = {"User-Agent": "Mozilla/5", "Referer": url}

        try:
            phone_url= "https://www.donedeal.ie/cadview/api/v3/view/ad/" + str(details_dict["id"]) + "/phone/"
            phone_request = requests.post(phone_url, headers = phone_headers)
            return json.loads(phone_request.text)
        except:
            return {"phone" : None}

    
    #----- Get page HTML code -----#
    headers = {'User-Agent':'Mozilla/5'}
    r = requests.get(url, headers = headers)
    html_contents = r.text
    html_soup = BeautifulSoup(html_contents, 'html.parser')
    
    #----- Obtain Main JSON Dictionary -----#
    scripts = html_soup.find_all('script')
    window_ad_details_script = [script for script in scripts if 'window.adDetails' in script.text][0]
    window_ad_details_script

    #----- Clean in order to represent as Python Dictionary -----#

    beginning = find_char_index(window_ad_details_script.text, '{')[0] # Begins at first opening bracket
    end = find_char_index(window_ad_details_script.text, '}')[-1] # Ends at last closing bracket

    window_ad_details_script_short = window_ad_details_script.text[beginning :end+1]
    window_ad_details_script_short

    details_dict = json.loads(window_ad_details_script_short)
    
    #----- Extract Data from Python Dictionary -----#

    # passing in list rather than string
    # https://stackoverflow.com/questions/17839973/constructing-pandas-dataframe-from-values-in-variables-gives-valueerror-if-usi

    # Contains car info as a dictionary as a list in a value of the main dictionary
    # The 'name' key contains the wanted key and similarly for 'value'
    # Only the first 14 elements contain car attributes

    car_attributes_list = details_dict["displayAttributes"][0:14]
    car_attributes_dict = {attribute["name"] : attribute["value"] for attribute in car_attributes_list}

    #----- Collect Data -----#
    
    # Obtaining values from keys directly can throw up a KeyValue error when it does not exist.
    # The method .get() is a safer way to access the dictionary

    data = {"ad_header" : details_dict.get("header"),
            "ad_description" : details_dict.get("description"),
            "ad_age" : details_dict.get("age"),
            "ad_id" : details_dict.get("id"),
            "ad_url" : [url],
            "ad_price" : details_dict.get("price"),
            "ad_currency" : details_dict.get("currency"),

            "seller_id" : details_dict.get("seller").get("id"),
            "seller_name" : details_dict.get("seller").get("name"),
            "seller_num_ads" : details_dict.get("seller").get("adCount"),
            "seller_type" : details_dict.get("seller").get("type"),
            "seller_county" : details_dict.get("seller").get("county"),
            "seller_county_town" : details_dict.get("seller").get("countyTown"),
            
            "seller_reg_date" : details_dict.get("seller").get("registrationDate"),

            "seller_phone_number" : [get_phone_number(url)["phone"]],

            "green_light_verified" : details_dict.get("greenlightVerified"),

            "car_make" : car_attributes_dict.get("make"),
            "car_model" : car_attributes_dict.get("model"),
            "car_year" : car_attributes_dict.get("year"),
            "car_mileage" : car_attributes_dict.get("mileage"),
            "car_fuel_type" : car_attributes_dict.get("fuelType"),
            "car_transmission" : car_attributes_dict.get("transmission"),
            "car_body_type" : car_attributes_dict.get("bodyType"),
            "car_engine" : car_attributes_dict.get("engine"),
            "car_road_tax" : car_attributes_dict.get("roadTax"),
            "car_nct_expiry" : car_attributes_dict.get("NCT"),
            "car_num_prev_owners" : car_attributes_dict.get("previousOwners"),
            "car_reg_country" : car_attributes_dict.get("country"),
            "car_colour" : car_attributes_dict.get("colour"),
            "car_num_doors" : car_attributes_dict.get("numDoors")
           }

    return pd.DataFrame.from_dict(data)

# %% [markdown]
# Test Function

# %%
# # Imports
# import pandas as pd
# import requests
# from bs4 import BeautifulSoup
# import json

url = 'https://www.donedeal.ie/cars-for-sale/very-clean-4x4/23802005'
get_info_from_ad_link(url)
# Out:
#    ad_age ad_currency                                     ad_description  \
# 0  4 days         EUR  Suzuki grand virara for sale.\r\nExcellent con...
#
#              ad_header     ad_id ad_price  \
# 0  Suzuki grand vitara  23802005    1,299
#
#                                               ad_url car_body_type car_colour  \
# 0  https://www.donedeal.ie/cars-for-sale/very-cle...           SUV        Red
#
#   car_engine     ...     car_year green_light_verified seller_county  \
# 0  1.6 litre     ...         2005                False       Donegal
#
#   seller_county_town seller_id seller_name seller_num_ads seller_phone_number  \
# 0         Carndonagh    146465        John              3                None
#
#            seller_reg_date seller_type
# 0  2009-09-20 23:02:31.154     PRIVATE
#
# [1 rows x 30 columns]

# %% [markdown]
# ## Function to gather links

# %%
def get_ad_links(max_links = 100):
    """
    Collects all car ads from DoneDeal
    Options to include number of links to collect
    Can later change criteria to automatically collect all ads
    """
    
    #----- Define custom functions -----#

    def generate_url(base_url, page_number):
        """
        Based on the structure of the donedeal website. 
        This function will returns the url given the desired page number
        """
        if page_number < 1:
            raise Exception("page_number cannot be less than 1")

        if page_number == 1:
            url = base_url
        else:
            extra_pages_url_addition = "&start={}".format(str((page_number - 1) * 28))
            url = base_url + extra_pages_url_addition

        return url  
    
    #----- Set up parameters -----#
    
    max_links = max_links
    base_url = 'https://www.donedeal.ie/cars?source=private'
    sub_str_car_add = "https://www.donedeal.ie/cars-for-sale"


    car_links = []
    page_number = 1
    status_code = 200

    headers = {'User-Agent':'Mozilla/5'}

    #----- Loop over pages based on stopping criteria -----#

    while len(car_links) < max_links and status_code == 200:

        url = generate_url(base_url, page_number = page_number)
        r = requests.get(url, headers = headers)
        status_code = r.status_code

        print("Scraping info from page number", page_number)
        print("url: ", url)

        if status_code == 200:

            html_contents = r.text
            html_soup = BeautifulSoup(html_contents, 'html.parser')

            all_links_on_page = html_soup.find_all('a', class_ = 'card__link', href = True)
            car_links_on_page = [link['href'] for link in all_links_on_page 
                                 if sub_str_car_add in link['href']]
            # Join lists together
            car_links = car_links + car_links_on_page

            # Update page number to get info from the next page
            page_number = page_number + 1

        else:

            print("Oops... This page returned the status code: ", status_code)
            print("The url ", url, " likely doesn't exist")

    print("We have collected ", len(car_links), " links to DoneDeal car adds")

    return car_links

# %% [markdown]
# Test Function

# %%
# car_links = get_ad_links(base_url, max_links = 100)

# %% [markdown]
# ## Function to generate table of ad info

# %%
def generate_table_of_ad_info(max_links = 100):
    """
    Function to get table of ad info
    """
    
    ad_columns = ["ad_header","ad_description","ad_age","ad_id","ad_url","ad_price","ad_currency","seller_id",
                  "seller_name","seller_num_ads","seller_type","seller_county","seller_county_town","seller_reg_date",
                  "seller_phone_number","green_light_verified","car_make","car_model","car_year","car_mileage","car_fuel_type",
                  "car_transmission","car_body_type","car_engine","car_road_tax","car_nct_expiry","car_num_prev_owners",
                  "car_reg_country","car_colour","car_num_doors"]

    ad_info_table = pd.DataFrame(columns = ad_columns)

    car_links = get_ad_links(max_links = 100)
    
    for i in car_links:
        # Clear print statements
        clear_output(wait = True)
        ad_info = get_info_from_ad_link(i)
        ad_info_table = ad_info_table.append(ad_info)
        print("Data collected for", str(len(ad_info_table)), "out of", str(len(car_links)), "ads")

    return ad_info_table

# %%
from IPython.display import clear_output

ad_info_table = generate_table_of_ad_info(max_links = 100)
# Out:
# Data collected for 132 out of 132 ads

# %%
ad_info_table
# Out:
#       ad_age ad_currency                                     ad_description  \
# 0      1 day         EUR  Nissan qashqai very well looked after,, like n...
# 0   15 hours         EUR  Skoda Octavia Diesel, Immaculate condition, Fu...
# 0     3 mins         EUR  2011 Toyota Avensis Estate 2.0D \nFull Main De...
# 0     3 mins         EUR  ABSOLUTELY BEAUTIFUL CAR IT REALLY IS LIKE NEW...
# 0    14 mins         EUR  AUTOMATIC HYUNDAI DELUX I 10 - 2015\n\nONLY 16...
# 0    15 mins         EUR  Manual 7 seater car for sale!  \r\n\r\n2.0 TDI...
# 0    19 mins         EUR  Car driving perfect   \nVery well maintained \...
# 0    20 mins         EUR  2005 Toyota Corolla 1.4 Strata 5dr\r\n\r\nIris...
# 0    22 mins         EUR                                Very good condition
# 0    29 mins         EUR  2005 ford fairlane cardinal 4 door hearse. Aut...
# 0    37 mins         EUR  FORD FIESTA\r\n\r\n2004\r\n\r\n5 DOOR\r\n\r\nN...
# 0    38 mins         EUR  Selling our 2014 Seat estate. \nThe car has re...
# 0    38 mins         EUR  Nct 5/2020\r\nAlloys\r\nHalf leather\r\nCentra...
# 0    42 mins         EUR  Audi S3, 1.8 Turbo ,4 wheel drive, it's in Exc...
# 0    44 mins         EUR  Audi Q3 Sline  131 D reg, one owner from new, ...
# 0    2 hours         EUR  LOOKS AND DRIVES GREAT , ALLOYS WAY GOOD TYRES...
# 0    4 hours         EUR  142 Ford Ranger Wildtrak 3.2\r\n\r\nMany extra...
# 0    6 hours         EUR
#
# 2.5L V6 , 210hp
# Taxed till 1/20/2020.
#  Nct t...
# 0    6 hours         EUR                                        Nct\nno Tax
# 0    7 hours         EUR  2011 BMW 520d SE Touring. 17” Alloys with good...
# 0    8 hours         EUR  2012 volkswagen passat for sale spec in the pi...
# 0    8 hours         EUR  Selling my bmw drives very smooth no issues ve...
# 0    8 hours         EUR  2007 Skoda Octavia model. 1.9 litre TDi Automa...
# 0    9 hours         EUR  Nissan Micra/March for sale. \n\nAutomatic tra...
# 0    9 hours         EUR  Selling my Honda.\r\nRuns very well. Reason im...
# 0    9 hours         EUR  Comfortline bluemotion mode,l vw bluetooth pho...
# 0    9 hours         EUR  2009 VW PASSAT 1.9TDI  COMFORT .. IRISH CAR .....
# 0    9 hours         EUR  Skoda Octavia 1.4\nElectric Windows , Power St...
# 0    9 hours         EUR  Here I have my very clean bmw 430d gran coupe ...
# 0    9 hours         EUR  Toyota\nYaris  2009\n1.4 Diesel\nRoad tax till...
# ..       ...         ...                                                ...
# 0   13 hours         EUR  Immaculate White  Fiat 500 1.2 Lounge electric...
# 0   13 hours         EUR  Central Locking \r\nElectric Windows \r\nElect...
# 0   13 hours         EUR  Please read first!!!!\n\n\n07 Skoda Octavia VR...
# 0   13 hours         EUR  AUDI S8  5.2L V10 450 BHP LAMBO ENGINE RARE SU...
# 0   13 hours         EUR  2010 SUZUKI SWIFT NCT 09 - 20 & TAXED 09 - 20 ...
# 0   13 hours         EUR  2012 FULL SPEC ALPHA WAGON ESTATE TOYOTA PRIUS...
# 0   13 hours         EUR  *** STRAIGHT SALE  **** NO SWAPS ***\r\n\r\nBM...
# 0   13 hours         GBP  New Clutch & Airflow Meter Full years MOT, gre...
# 0   13 hours         EUR  Honda CR-V for sale\nRuns great\nSunroof\nAll ...
# 0   13 hours         EUR  Sold with full recent Motorcheck\r\n\r\nFord M...
# 0   13 hours         EUR  Formula Vee is the entry level class for singl...
# 0   13 hours         EUR  2012 Golf 1.6 TDI\n128000 Km\nT. Belt kit just...
# 0   13 hours         EUR  Volkswagen Golf 2.0 Golf Gt Tdi. 6 speed gear ...
# 0   13 hours         EUR  2012 vauxhall insignia  130bhp  6 speed manual...
# 0   14 hours         EUR  October 2015 Hyundai i10 \n9000 miles\n998cc\n...
# 0   14 hours         GBP  🔥 2014 SEAT MII TOCA 1.0 PETROL BLUE 3 DOOR **...
# 0   14 hours         EUR  I have for sale Honda FR-V 1.7 petrol 06 plate...
# 0   14 hours         EUR  06 407 petrol \n1.8 engine \nVery economical o...
# 0   14 hours         EUR  NCT tested till 09/20 \n2.0 diesel\nBlack leat...
# 0   14 hours         EUR  01 yaris \nAbsolutely mint condition \nDrives ...
# 0   14 hours         EUR  03 golf \n3dr \n1.4 petrol \nVery clean \nDriv...
# 0   14 hours         EUR  For sale 06 Toyota Corolla 1.4 petrol 14 month...
# 0   14 hours         EUR  2007 Bmw 320i Coupe M-Sport E90\r\nNCT Valid t...
# 0   14 hours         EUR  152 Sportage Axis Edition,really eye catching ...
# 0   14 hours         EUR  2018 Kia niro, full hybrid no plugging in in t...
# 0   14 hours         EUR  08 Audi A6 2.0 tdi automatic\nFull black leath...
# 0   14 hours         EUR  Nice clean car \nDrives 100% \nEverything work...
# 0     8 days         EUR  Opel Insignia S 2.0cdti 130PS 4DR 13 (2013)\n\...
# 0     8 days         EUR  Mitsubishi Outlander 2.2 Di-d GX3 4WD 148 14 (...
# 0     9 days         EUR  Volkswagen CC 2.0 TDI GT BMT 140PS 5ST 4D 15 (...
#
#                                             ad_header     ad_id ad_price  \
# 0                                  Car Nissan qashqai  23809138    9,750
# 0            132 1.6tdi Ambition Skoda Octavia Estate  23609135    6,750
# 0                           Toyota Avensis Estate FSH  23761659    4,650
# 0            2016 OPEL INSIGNIA LOW MILEAGE IRISH CAR  23782038    9,600
# 0   16 k Miles - 998 cc Auto Hyundai Delux i 10 - ...  23722633    8,895
# 0                         Ford S-max 2.0 Tdi 7 Seater  23363577   11,850
# 0                            2009 Ford Focus 1.8 tdci  23527430    2,100
# 0                 2005 Toyota Corolla 1.4i Strata 5dr  23653318      950
# 0                                                 Car  23734144    1,250
# 0                            Hearse/removal ambulance  23433837   11,000
# 0       FORD FIESTA NCT 02-20 TAX 10-20 5 DR *LOW KM*  23059787      395
# 0             Seat Leon estate FR technology 2ltr TDI  23668686   11,850
# 0                              Opel/vauxhall insignia  23793703    2,450
# 0                 Audi S3    4wheel Drive    1.8Turbo  23458416    4,250
# 0                           131 Audi Q3 S Line 1owner  23519222   14,800
# 0                       Nissan Qashqai 1,5 disel 2011  23341531    5,500
# 0                            142 FORD RANGER WILDTRAK  23733868   17,000
# 0                                   2007 Lexus Is 250  23731626    4,000
# 0                          Mercedes CLK200 Avantgarde  23813408      550
# 0                            2011 BMW 520d SE Touring  23180077    9,250
# 0           2012 volkswagen passat nct till feb-2022!  23490956    3,650
# 0                                        Bmw 1 series  23813387    1,100
# 0   2007 Skoda Octavia model. 1.9 litre TDi Automatic  23813360    1,600
# 0                         Nissan Micra 2006 automatic  23813358    1,750
# 0                                   2006 Honda Accord  23279371    1,500
# 0                                           11 Passat  23358479    5,500
# 0                  2009 VW PASSAT 1.9TDI .. IRISH CAR  23805379    3,450
# 0                  Skoda Octavia 1.4 LONG NCT AND TAX  23810539    1,350
# 0        ♦️BMW 430 grand coupe 258BHP♦️    PRICE DROP  23200079   25,950
# 0                     Toyota Yaris diesel NCT 09/2021  23813336    3,650
# ..                                                ...       ...      ...
# 0                                 Fiat 500 1.2 Lounge  22225733    4,500
# 0                                  VW  GOLF. 1.6  TDI  23799897    5,950
# 0                                07 Skoda Octavia VRS  23663622    1,250
# 0            LAMBO POWERED AUDI _S8 _5.2_ V10 _450BHP  21369220   12,999
# 0   2010 SUZUKI SWIFT  09-20NCT TAX09-20.-CHEAP  €...  23791096    2,222
# 0   2012 toyota prius hybrid auto 04-21NCT&TAX .€9900  23791038    9,900
# 0                                           BMW 730LD  21399648   15,500
# 0                               2008 Ford Fiesta TDCI  23446594    1,050
# 0                                          Honda CR-V  23813027    2,000
# 0                           2015 Ford Mondeo 1.6 TDCI  22227074   10,200
# 0                  Formula Vee 2020 - DRIVERS WANTED!  20643514        1
# 0          2012 Golf 1.6 TDI.... Match.  ...NCT 12/21  23749288    8,650
# 0                                  Vw Golf 2.0 Gt Tdi  23813014    6,200
# 0                              2012 Vauxhall Insignia  23283096    3,800
# 0                                         Hyundai i10  23701663    3,950
# 0     🔥 2014 SEAT MII TOCA 1.0 PETROL BLUE UP CITIGO🔥  23732305    2,995
# 0                  Honda FRV 1.7 petrol 2006 6 seater  23701894      550
# 0                                    06 407 NCT 10/20  23403438      990
# 0                              S40 Automatic Nct 9/20  22923423    1,490
# 0                                            01 Yaris  23164292      850
# 0                                         03 Golf 1.4  23113044      500
# 0          FINAL PRICE DROP 06 COROLLA 14  MONTHS NCT  23527839    1,250
# 0                              Bmw 320i Coupe M-Sport  23812971    3,850
# 0                           152 Sportage Axis Edition  23693141   10,500
# 0    Kia Niro, Full HYBRID 181 with very low mileage.  23104950   26,995
# 0      08 audi a 6 2.0 tdi automatic leather interior  23522097    3,000
# 0                         Mercedes E200 ncted + taxed  23812957    1,850
# 0                   Opel Insignia S 2.0cdti 130PS 4DR  23771406    7,500
# 0           Mitsubishi Outlander 2.2 Di-d GX3 4WD 148  23771327   16,900
# 0           Volkswagen CC 2.0 TDI GT BMT 140PS 5ST 4D  23767686   17,900
#
#                                                ad_url car_body_type  \
# 0   https://www.donedeal.ie/cars-for-sale/car-niss...           SUV
# 0   https://www.donedeal.ie/cars-for-sale/132-1-6t...        Estate
# 0   https://www.donedeal.ie/cars-for-sale/toyota-a...        Estate
# 0   https://www.donedeal.ie/cars-for-sale/2016-ope...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/16-k-mil...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/ford-s-m...           MPV
# 0   https://www.donedeal.ie/cars-for-sale/2009-for...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/2005-toy...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/car/2373...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/hearse-r...           n/a
# 0   https://www.donedeal.ie/cars-for-sale/ford-fie...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/seat-leo...        Estate
# 0   https://www.donedeal.ie/cars-for-sale/opel-vau...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/audi-s3-...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/131-audi...           SUV
# 0   https://www.donedeal.ie/cars-for-sale/nissan-q...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/142-ford...      Crew Cab
# 0   https://www.donedeal.ie/cars-for-sale/2007-lex...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/mercedes...         Coupe
# 0   https://www.donedeal.ie/cars-for-sale/2011-bmw...        Estate
# 0   https://www.donedeal.ie/cars-for-sale/2012-vol...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/bmw-1-se...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/2007-sko...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/nissan-m...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/2006-hon...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/11-passa...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/2009-vw-...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/skoda-oc...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/bmw-430-...         Coupe
# 0   https://www.donedeal.ie/cars-for-sale/toyota-y...     Hatchback
# ..                                                ...           ...
# 0   https://www.donedeal.ie/cars-for-sale/fiat-500...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/vw-golf-...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/07-skoda...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/lambo-po...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/2010-suz...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/2012-toy...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/bmw-730l...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/2008-for...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/honda-cr...           SUV
# 0   https://www.donedeal.ie/cars-for-sale/2015-for...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/formula-...
# 0   https://www.donedeal.ie/cars-for-sale/2012-gol...        Estate
# 0   https://www.donedeal.ie/cars-for-sale/vw-golf-...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/2012-vau...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/hyundai-...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/2014-sea...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/honda-fr...           MPV
# 0   https://www.donedeal.ie/cars-for-sale/06-407-n...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/s40-auto...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/01-yaris...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/03-golf-...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/final-pr...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/bmw-320i...         Coupe
# 0   https://www.donedeal.ie/cars-for-sale/152-spor...           SUV
# 0   https://www.donedeal.ie/cars-for-sale/kia-niro...           SUV
# 0   https://www.donedeal.ie/cars-for-sale/08-audi-...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/mercedes...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/opel-ins...           MPV
# 0   https://www.donedeal.ie/cars-for-sale/mitsubis...           SUV
# 0   https://www.donedeal.ie/cars-for-sale/volkswag...         Coupe
#
#    car_colour car_engine     ...     car_year green_light_verified  \
# 0        Grey  1.6 litre     ...         2012                 True
# 0       Beige  1.6 litre     ...         2013                False
# 0        Grey  2.0 litre     ...         2011                 True
# 0       Black  1.6 litre     ...         2016                 True
# 0        Grey  1.0 litre     ...         2015                 True
# 0      Silver  2.0 litre     ...         2014                 True
# 0              1.8 litre     ...         2009                False
# 0      Silver  1.4 litre     ...         2005                 True
# 0         Red  1.8 litre     ...         2006                False
# 0       Black                ...         2005                False
# 0      Silver  1.4 litre     ...         2004                 True
# 0        Grey  2.0 litre     ...         2014                 True
# 0        Grey  2.0 litre     ...         2010                 True
# 0       Black  1.8 litre     ...         2003                False
# 0       White  2.0 litre     ...         2013                False
# 0         Red  1.5 litre     ...         2011                 True
# 0        Grey  3.2 litre     ...         2014                False
# 0       Black  2.5 litre     ...         2007                False
# 0       Black  2.0 litre     ...         2002                False
# 0        Blue  2.0 litre     ...         2011                 True
# 0        Grey  2.0 litre     ...         2012                False
# 0       Black  1.6 litre     ...         2007                False
# 0       Beige  1.9 litre     ...         2007                False
# 0      Silver  1.2 litre     ...         2006                False
# 0        Grey  2.2 litre     ...         2006                 True
# 0       Brown  1.6 litre     ...         2011                False
# 0      Silver  2.0 litre     ...         2009                False
# 0      Silver  1.4 litre     ...         2006                 True
# 0      Silver  3.0 litre     ...         2015                 True
# 0      Silver  1.4 litre     ...         2009                 True
# ..        ...        ...     ...          ...                  ...
# 0       White  1.2 litre     ...         2010                 True
# 0       White  1.6 litre     ...         2011                False
# 0      Silver  2.0 litre     ...         2007                False
# 0        Grey  5.2 litre     ...         2006                 True
# 0        Blue  1.3 litre     ...         2010                 True
# 0        Grey  1.8 litre     ...         2012                 True
# 0       Black  3.0 litre     ...         2013                 True
# 0        Blue  1.4 litre     ...         2008                False
# 0        Grey  2.0 litre     ...         2006                False
# 0        Grey  1.6 litre     ...         2015                 True
# 0              1.6 litre     ...         2019                False
# 0       Black  1.6 litre     ...         2012                False
# 0       White  2.0 litre     ...         2009                False
# 0        Blue  2.0 litre     ...         2012                False
# 0        Blue  1.0 litre     ...         2015                False
# 0        Blue  1.0 litre     ...         2014                False
# 0        Blue  1.7 litre     ...         2006                False
# 0        Grey  1.7 litre     ...         2006                 True
# 0      Silver  2.0 litre     ...         2009                False
# 0      Silver  1.0 litre     ...         2001                False
# 0      Silver  1.4 litre     ...         2003                 True
# 0        Blue  1.4 litre     ...         2006                 True
# 0        Blue  2.0 litre     ...         2007                 True
# 0      Silver  1.7 litre     ...         2015                False
# 0        Grey  1.6 litre     ...         2018                False
# 0        Grey  2.0 litre     ...         2008                False
# 0        Grey  1.8 litre     ...         2005                False
# 0      Silver  2.0 litre     ...         2013                 True
# 0       White  2.3 litre     ...         2014                 True
# 0        Grey  2.0 litre     ...         2015                 True
#
#    seller_county seller_county_town seller_id       seller_name  \
# 0         Dublin       South County   1463616             harry
# 0        Leitrim               None    147276            Seller
# 0        Wicklow               None    905642             Peter
# 0       Limerick               None   1092178              call
# 0         Dublin        City Centre    739240             brian
# 0      Waterford     Waterford City    363336                RR
# 0          Cavan               None    199182              Alan
# 0          Louth              Ardee   1059015             James
# 0          Laois               None   1567568            benson
# 0        Donegal       Ballyshannon    255920     jackie carron
# 0       Limerick     Newcastle West   3250376               Pat
# 0       Longford     Edgeworthstown    299461     Kristo Dawson
# 0          Cavan         Cavan Town   2022021               ian
# 0         Dublin               None    120212       James Fagan
# 0         Dublin               None    120212       James Fagan
# 0        Wicklow         Greystones   3336281            Robert
# 0          Clare               None     31356              John
# 0           Cork               None   3393243              dexx
# 0          Laois               None   1193230              Miha
# 0       Limerick      Limerick City    141519       Jeff Cussen
# 0           Cork               Cobh   2002071             Shane
# 0           None               None   3394865           HASHMAT
# 0         Dublin               None   2928731  Ghenadie Godorog
# 0         Dublin               None     43784          Wishbone
# 0        Wexford               None   3335363     Scott kendall
# 0          Clare    Milltown Malbay      6733              tony
# 0         Dublin        City Centre     55933               TOM
# 0          Kerry          Killarney   1878685             Irene
# 0        Kildare               Naas     44855           Skyline
# 0       Longford               None   3377037          K Bashir
# ..           ...                ...       ...               ...
# 0         Dublin         South City   3244143              Kate
# 0           Cork             Bandon    714176           Michael
# 0         Galway               Gort     82793               Ian
# 0         Dublin               None   2590077                 j
# 0         Dublin               None     26914                 m
# 0         Dublin               None     26914                 m
# 0         Dublin               None    595434               Bmw
# 0         Tyrone         Castlederg    729247            Kieran
# 0           None               None   3145138            Mouric
# 0       Kilkenny               None      9510    Bouncy Castles
# 0        Kildare              Clane    658395    Stephen Morrin
# 0        Wexford               None   1089084            seller
# 0          Cavan               None    206854                 .
# 0          Cavan          Cootehill    629270            Robert
# 0       Monaghan      Monaghan Town     94549           Christy
# 0         Tyrone              Omagh    143606                 A
# 0       Monaghan               None   2608445          Jonathan
# 0      Tipperary             Cashel    150619         john ward
# 0      Tipperary             Cashel    150619         john ward
# 0      Tipperary             Cashel    150619         john ward
# 0      Tipperary             Cashel    150619         john ward
# 0       Limerick      Limerick City   1190815               Pat
# 0         Dublin       North County   1504625        moelkhaldy
# 0       Monaghan               None    555856             PADDY
# 0           Mayo            Ballina    225973            Seller
# 0          Kerry          Killarney     31345            seller
# 0         Dublin               None   1035688            ashley
# 0           None               None   2858143    kearyscarstore
# 0           None               None   2858143    kearyscarstore
# 0           None               None   2858143    kearyscarstore
#
#    seller_num_ads seller_phone_number          seller_reg_date seller_type
# 0               1                None  2010-03-29 18:48:24.607     PRIVATE
# 0               1                None  2010-01-11 20:30:10.063     PRIVATE
# 0               1                None  2014-03-10 08:24:23.529     PRIVATE
# 0               5                None  2014-07-16 14:23:34.041     PRIVATE
# 0               3                None   2010-03-21 22:19:26.56     PRIVATE
# 0               2                None  2010-03-01 16:12:32.703     PRIVATE
# 0               1                None  2012-01-21 11:21:00.255     PRIVATE
# 0               3                None  2014-06-26 16:00:40.479     PRIVATE
# 0               1                None  2011-11-12 23:38:25.445     PRIVATE
# 0               2                None  2009-09-17 21:18:40.196     PRIVATE
# 0               1                None  2019-06-28 21:18:27.507     PRIVATE
# 0               2                None  2012-08-13 14:40:11.183     PRIVATE
# 0               1                None   2015-10-01 13:34:29.89     PRIVATE
# 0               3                None  2011-08-14 16:43:47.139     PRIVATE
# 0               3                None  2011-08-14 16:43:47.139     PRIVATE
# 0               1                None  2019-10-21 18:32:15.422     PRIVATE
# 0               6                None  2010-07-07 08:41:19.724     PRIVATE
# 0               1                None   2019-12-11 19:01:05.08     PRIVATE
# 0               1                None  2010-03-10 16:49:54.406     PRIVATE
# 0               1                None  2011-04-24 16:50:42.221     PRIVATE
# 0               1                None  2015-09-14 18:33:49.869     PRIVATE
# 0               1                None  2019-12-15 01:53:23.244     PRIVATE
# 0               1                None   2018-05-13 21:58:17.01     PRIVATE
# 0               1                None  2010-07-25 15:27:11.033     PRIVATE
# 0               3                None  2019-10-20 12:33:24.167     PRIVATE
# 0               1                None  2010-09-04 22:49:52.838      TRADER
# 0               2                None  2009-09-15 21:24:42.542     PRIVATE
# 0               1                None   2015-06-16 19:10:57.63     PRIVATE
# 0               1                None  2008-11-20 23:44:02.833     PRIVATE
# 0               1                None  2019-11-18 17:57:52.691     PRIVATE
# ..            ...                 ...                      ...         ...
# 0               1                None   2019-06-20 17:40:43.65     PRIVATE
# 0               2                None  2013-08-31 14:15:44.805     PRIVATE
# 0               2                None  2009-06-20 16:43:39.325     PRIVATE
# 0               1                None   2017-03-28 20:42:46.47     PRIVATE
# 0              13                None  2008-07-30 22:29:26.001     PRIVATE
# 0              13                None  2008-07-30 22:29:26.001     PRIVATE
# 0               1                None  2010-06-25 10:30:38.335     PRIVATE
# 0               3                None  2013-09-11 17:34:21.925     PRIVATE
# 0               1                None  2019-02-18 14:54:59.664     PRIVATE
# 0               1                None  2011-05-11 14:44:10.089     PRIVATE
# 0               1                None  2013-07-12 16:28:11.044     PRIVATE
# 0               1                None  2014-07-14 19:53:27.375     PRIVATE
# 0               1                None  2009-10-25 15:28:24.066     PRIVATE
# 0               1                None  2013-06-13 23:26:45.385     PRIVATE
# 0               3                None  2010-04-20 21:41:53.286     PRIVATE
# 0               8                None  2011-02-24 19:40:25.628     PRIVATE
# 0               1                None  2017-04-18 19:03:42.202     PRIVATE
# 0               9                None  2010-04-05 20:27:26.333     PRIVATE
# 0               9                None  2010-04-05 20:27:26.333     PRIVATE
# 0               9                None  2010-04-05 20:27:26.333     PRIVATE
# 0               9                None  2010-04-05 20:27:26.333     PRIVATE
# 0               1                None  2014-09-19 18:22:40.692     PRIVATE
# 0               1                None  2015-05-20 20:13:32.891     PRIVATE
# 0               2                None   2013-04-02 21:44:31.07     PRIVATE
# 0               2                None  2011-01-04 21:24:35.046     PRIVATE
# 0               5                None  2009-10-30 17:27:40.032     PRIVATE
# 0               4                None  2011-09-24 10:24:02.612     PRIVATE
# 0               0                None  2018-02-12 11:58:13.794      DEALER
# 0               0                None  2018-02-12 11:58:13.794      DEALER
# 0               0                None  2018-02-12 11:58:13.794      DEALER
#
# [132 rows x 30 columns]

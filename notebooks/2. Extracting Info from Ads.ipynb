# %% [markdown]
# # Extracting Info from Ads
#
# `Author: James Smith`
#
# `Date: 22/12/2019`

# %% [markdown]
# Given an add link, we want to extract all information that we want from it
#
# - Phone Number - using workaround
# - All other info - using JSON dictionary located at bottom of page code
#
# Example Ad: https://www.donedeal.ie/cars-for-sale/very-clean-4x4/23802005

# %% [markdown]
# ## Function to get info from ad link

# %%
def get_info_from_ad_link(url):
    """
    Given a url it returns a dataframe of info
    """
    
    #----- Define custom functions -----#
    
    def find_char_index(s, ch):
        """
        Function to return indexes of a character in a given string
        https://stackoverflow.com/questions/11122291/how-to-find-char-in-string-and-get-all-the-indexes
        """
        return [i for i, ltr in enumerate(s) if ltr == ch]
    
    def get_phone_number(url):
        """
        Given a url this function return a dictionary containing 
        the sellers phone number.
        Returns None if an error occurs
        This happens due to frequent scraping - "Please contact customer support"
        """
        phone_headers = {"User-Agent": "Mozilla/5", "Referer": url}

        try:
            phone_url= "https://www.donedeal.ie/cadview/api/v3/view/ad/" + str(details_dict["id"]) + "/phone/"
            phone_request = requests.post(phone_url, headers = phone_headers)
            return json.loads(phone_request.text)
        except:
            return {"phone" : None}

    
    #----- Get page HTML code -----#
    headers = {'User-Agent':'Mozilla/5'}
    r = requests.get(url, headers = headers)
    html_contents = r.text
    html_soup = BeautifulSoup(html_contents, 'html.parser')
    
    #----- Obtain Main JSON Dictionary -----#
    scripts = html_soup.find_all('script')
    window_ad_details_script = [script for script in scripts if 'window.adDetails' in script.text][0]
    window_ad_details_script

    #----- Clean in order to represent as Python Dictionary -----#

    beginning = find_char_index(window_ad_details_script.text, '{')[0] # Begins at first opening bracket
    end = find_char_index(window_ad_details_script.text, '}')[-1] # Ends at last closing bracket

    window_ad_details_script_short = window_ad_details_script.text[beginning :end+1]
    window_ad_details_script_short

    details_dict = json.loads(window_ad_details_script_short)
    
    #----- Extract Data from Python Dictionary -----#

    # passing in list rather than string
    # https://stackoverflow.com/questions/17839973/constructing-pandas-dataframe-from-values-in-variables-gives-valueerror-if-usi

    # Contains car info as a dictionary as a list in a value of the main dictionary
    # The 'name' key contains the wanted key and similarly for 'value'
    # Only the first 14 elements contain car attributes

    car_attributes_list = details_dict["displayAttributes"][0:14]
    car_attributes_dict = {attribute["name"] : attribute["value"] for attribute in car_attributes_list}

    #----- Collect Data -----#
    
    # Obtaining values from keys directly can throw up a KeyValue error when it does not exist.
    # The method .get() is a safer way to access the dictionary

    data = {"ad_header" : details_dict.get("header"),
            "ad_description" : details_dict.get("description"),
            "ad_age" : details_dict.get("age"),
            "ad_id" : details_dict.get("id"),
            "ad_url" : [url],
            "ad_price" : details_dict.get("price"),
            "ad_currency" : details_dict.get("currency"),

            "seller_id" : details_dict.get("seller").get("id"),
            "seller_name" : details_dict.get("seller").get("name"),
            "seller_num_ads" : details_dict.get("seller").get("adCount"),
            "seller_type" : details_dict.get("seller").get("type"),
            "seller_county" : details_dict.get("seller").get("county"),
            "seller_county_town" : details_dict.get("seller").get("countyTown"),
            
            "seller_reg_date" : details_dict.get("seller").get("registrationDate"),

            "seller_phone_number" : [get_phone_number(url)["phone"]],

            "green_light_verified" : details_dict.get("greenlightVerified"),

            "car_make" : car_attributes_dict.get("make"),
            "car_model" : car_attributes_dict.get("model"),
            "car_year" : car_attributes_dict.get("year"),
            "car_mileage" : car_attributes_dict.get("mileage"),
            "car_fuel_type" : car_attributes_dict.get("fuelType"),
            "car_transmission" : car_attributes_dict.get("transmission"),
            "car_body_type" : car_attributes_dict.get("bodyType"),
            "car_engine" : car_attributes_dict.get("engine"),
            "car_road_tax" : car_attributes_dict.get("roadTax"),
            "car_nct_expiry" : car_attributes_dict.get("NCT"),
            "car_num_prev_owners" : car_attributes_dict.get("previousOwners"),
            "car_reg_country" : car_attributes_dict.get("country"),
            "car_colour" : car_attributes_dict.get("colour"),
            "car_num_doors" : car_attributes_dict.get("numDoors")
           }

    return pd.DataFrame.from_dict(data)

# %% [markdown]
# Test Function

# %%
# # Imports
# import pandas as pd
# import requests
# from bs4 import BeautifulSoup
# import json

url = 'https://www.donedeal.ie/cars-for-sale/very-clean-4x4/23802005'
get_info_from_ad_link(url)
# Out:
#    ad_age ad_currency                                     ad_description  \
# 0  4 days         EUR  Suzuki grand virara for sale.\r\nExcellent con...
#
#              ad_header     ad_id ad_price  \
# 0  Suzuki grand vitara  23802005    1,299
#
#                                               ad_url car_body_type car_colour  \
# 0  https://www.donedeal.ie/cars-for-sale/very-cle...           SUV        Red
#
#   car_engine     ...     car_year green_light_verified seller_county  \
# 0  1.6 litre     ...         2005                False       Donegal
#
#   seller_county_town seller_id seller_name seller_num_ads seller_phone_number  \
# 0         Carndonagh    146465        John              3                None
#
#            seller_reg_date seller_type
# 0  2009-09-20 23:02:31.154     PRIVATE
#
# [1 rows x 30 columns]

# %% [markdown]
# ## Function to gather links

# %%
def get_ad_links(max_links):
    """
    Collects all car ads from DoneDeal
    Options to include number of links to collect
    Can later change criteria to automatically collect all ads
    """
    
    #----- Define custom functions -----#

    def generate_url(base_url, page_number):
        """
        Based on the structure of the donedeal website. 
        This function will returns the url given the desired page number
        """
        if page_number < 1:
            raise Exception("page_number cannot be less than 1")

        if page_number == 1:
            url = base_url
        else:
            extra_pages_url_addition = "&start={}".format(str((page_number - 1) * 28))
            url = base_url + extra_pages_url_addition

        return url  
    
    #----- Set up parameters -----#
    
    max_links = max_links
    base_url = 'https://www.donedeal.ie/cars?source=private'
    sub_str_car_add = "https://www.donedeal.ie/cars-for-sale"


    car_links = []
    page_number = 1
    status_code = 200

    headers = {'User-Agent':'Mozilla/5'}

    #----- Loop over pages based on stopping criteria -----#

    while len(car_links) < max_links and status_code == 200:

        url = generate_url(base_url, page_number = page_number)
        r = requests.get(url, headers = headers)
        status_code = r.status_code

        print("Scraping info from page number", page_number)
        print("url: ", url)

        if status_code == 200:

            html_contents = r.text
            html_soup = BeautifulSoup(html_contents, 'html.parser')

            all_links_on_page = html_soup.find_all('a', class_ = 'card__link', href = True)
            car_links_on_page = [link['href'] for link in all_links_on_page 
                                 if sub_str_car_add in link['href']]
            # Join lists together
            car_links = car_links + car_links_on_page

            # Update page number to get info from the next page
            page_number = page_number + 1

        else:

            print("Oops... This page returned the status code: ", status_code)
            print("The url ", url, " likely doesn't exist")

    print("We have collected ", len(car_links), " links to DoneDeal car adds")

    return car_links

# %% [markdown]
# Test Function

# %%
# car_links = get_ad_links(base_url, max_links = 100)

# %% [markdown]
# ## Function to generate table of ad info

# %%
def generate_table_of_ad_info(max_links):
    """
    Function to get table of ad info
    """
    
    ad_columns = ["ad_header","ad_description","ad_age","ad_id","ad_url","ad_price","ad_currency","seller_id",
                  "seller_name","seller_num_ads","seller_type","seller_county","seller_county_town","seller_reg_date",
                  "seller_phone_number","green_light_verified","car_make","car_model","car_year","car_mileage","car_fuel_type",
                  "car_transmission","car_body_type","car_engine","car_road_tax","car_nct_expiry","car_num_prev_owners",
                  "car_reg_country","car_colour","car_num_doors"]

    ad_info_table = pd.DataFrame(columns = ad_columns)

    car_links = get_ad_links(max_links = max_links)
    
    for i in car_links:
        # Error handling, will try next iteration if it fails
        try:
            # Clear print statements
            clear_output(wait = True)
            ad_info = get_info_from_ad_link(i)
            ad_info_table = ad_info_table.append(ad_info)
            print("Data collected for", str(len(ad_info_table)), "out of", str(len(car_links)), "ads")
        except:
            pass
        
    return ad_info_table

# %%
from IPython.display import clear_output

ad_info_table = generate_table_of_ad_info(max_links = 10000)
# Out:
# Data collected for 10007 out of 10021 ads

# %%
ad_info_table
# Out:
#       ad_age ad_currency                                     ad_description  \
# 0    5 hours         EUR  VW CC GT in excellent condition with 67 mile o...
# 0    11 days         EUR  2007 mercedes c180 PETROL 1.8 cc.\r\n NCT NOVE...
# 0     7 mins         EUR  Hello selling my snow white Ford Focus mk3  20...
# 0     8 mins         EUR  Tax 5/20\nNct 14/2/20\n1.6 hdi 7 seater\nAll g...
# 0    12 mins         EUR  A very good car drives great new NCT call for ...
# 0    14 mins         EUR  2007 Toyota Corolla 1.4 diesel serviced 2thous...
# 0    16 mins         EUR  2006 Micra Sport for sale in Dublin with low m...
# 0    16 mins         EUR  Renault Scenic, 2004  \r\nClean and good condi...
# 0    17 mins         EUR  I am selling my golf, It is a 152 gti with the...
# 0    19 mins         EUR  Nissan qashqai for sale \nIn great condition \...
# 0    19 mins         EUR  1 owner car from new, only 114kms, running per...
# 0    20 mins         EUR  Only 76k kilometers\nStill under Kia warranty ...
# 0    22 mins         EUR  Toyota auris 11  d4d engine bags out was mint ...
# 0    23 mins         EUR  Forsale Vauxhall Astra, 1.3 diesel.Good  car, ...
# 0    23 mins         EUR  2012 Nice Audi A5 cabriolet, s-line,  fresh Nc...
# 0    25 mins         EUR  Great driving economical 7 seater.Nct &tax.All...
# 0    25 mins         EUR  DIESEL\n\n€4350 Euro\n\nA/C\n\nC/C\n\nBluetoot...
# 0    25 mins         EUR  Great driving economical 1'4 diesel fiesta.Nct...
# 0    26 mins         EUR  2013 Peugeot 508. 130000 kms. Diesel. Manual. ...
# 0    26 mins         EUR  Hi selling my Toyota come With 2 keys.  car is...
# 0    28 mins         EUR  16 vauxhall corsa 1.4 limited edition....alloy...
# 0    29 mins         EUR  Ford focus  car 05  not sure what's  wrong wit...
# 0    30 mins         EUR  Mercedes  2.2 CDI\r\n05    manual    diesel\r\...
# 0    30 mins         GBP  2012 Audi A4 2.0tdi Technik\nUK company owned ...
# 0    31 mins         EUR  14 vauxhall agila.1.0.....5dr.....32k....cd pl...
# 0    33 mins         EUR  08 Mazda 2, 1.4 diesel for sale.\n Cheep tax, ...
# 0    36 mins         EUR  Renault Megane GT Line estate 1.6 dci 130bhp\r...
# 0    38 mins         EUR  MINI ONE SPORT 🥎 LIMITED EDITION WITH BEAUTIFU...
# 0    38 mins         EUR  VW polo 1.4 diesel 2009 bluemotion\r\n189000mi...
# 0    38 mins         EUR  Very good car, black leather interior , 4 new ...
# ..       ...         ...                                                ...
# 0    17 days         EUR  This is the Premium version that comes with me...
# 0    17 days         EUR  Hi...\nSelling a nice family car \n( Toyota co...
# 0    17 days         EUR  2.0 TDi SE 134 BHP manual\nTax €280 pa co2 139...
# 0    17 days         EUR  Selling my black BMW 320i in show room conditi...
# 0    17 days         EUR  162 Kia Sportage\r\n\r\nExcellent condition, w...
# 0    17 days         EUR  2010 Nissan Note 1.4 16V-TEC.  \nSAT NAV.\nBlu...
# 0    17 days         EUR  New battery and new fan belt just fitted,  nct...
# 0    17 days         EUR  2003 MK4 Volkswagen Golf GTI 5 Door Hatch\n\n1...
# 0    17 days         EUR  ***S-LINE BLACK EDYTION ULTRA 190 BHP***\r\nfu...
# 0    17 days         EUR  Good Toyota Yaris from year 2000\r\n\r\n- NCT ...
# 0    17 days         EUR  2009 mercedes, fully serviced and tested. Very...
# 0    17 days         EUR  2009 Audi A6 2.0 TDI 140 BHP AUTOMATIC\n\n-NCT...
# 0    17 days         EUR  Very good car you have extra remote too start ...
# 0    17 days         EUR  Very nice car, only 49950klm. I have all prof ...
# 0    17 days         GBP  2013 VAUXHALL INSIGNIA ESTATE, AUTO 2.0 DIESEL...
# 0    17 days         EUR  Hyundai i30 estate\nGood condition \nLow tax\n...
# 0    17 days         EUR  Audi A4 Avant Estate \n\nRecently Serviced \nT...
# 0    17 days         EUR  LOW MILEAGE\nImmaculate condition inside and o...
# 0    17 days         EUR  Taxed till January 2020 and NCT till February ...
# 0    17 days         EUR  Selling this 06 golf drives absolutely perfect...
# 0    17 days         EUR  Absolutely beautiful 520d automatic 190 bhp .T...
# 0    17 days         EUR  Mercedes E-Class Nct In Daily use, Some body s...
# 0    17 days         EUR  Great car low km two owners just pasted NCT tw...
# 0    17 days         GBP  5000 if gone this weekend\nMitsubishi gto twin...
# 0    17 days         EUR  This car is absolutely immaculate. \r\nTop spe...
# 0    17 days         EUR  Good condition Volkswagen Golf 1.4 L Petrol fo...
# 0    17 days         EUR  Great condition inside and out\r\nDrives like ...
# 0    8 hours         EUR  Dacia Sandero Stepway Alternative 17 (2017)\n\...
# 0   23 hours         EUR  Renault KADJAR Dynamique NAV Energy\n\nDrop in...
# 0      1 day         EUR  Renault Zoe Dynamique NAV R110 Z.e. 40\n\nFina...
#
#                                            ad_header     ad_id ad_price  \
# 0                      Volkswagen CC GT (price drop)  22850112   13,000
# 0                   Mercedes c180 NCT NOV 2020 taxed  23728903    1,495
# 0    Ford Focus mk3 2011 1.6 tdci zetec Nct 01.08.21  23749372    5,599
# 0              Peugeot 307 1.6hdi 7 seater tax & nct  23753474      675
# 0                                         Volkswagen  23815100   10,500
# 0                                2007 Toyota Corolla  23792855    1,575
# 0                            2006 Nissan Micra Sport  23815086    1,250
# 0                                Renault scenic 2004  23815087      300
# 0                       Golf gti performance 230 bhp  23395706   22,500
# 0                            Nissan qashqai for sale  23525665    2,000
# 0        Nissan Tida, only 114kms, 1 owner from new.  23815063      575
# 0                                  Kia Sportage 2014  23756082   13,450
# 0                               Toyota auris crashed  23815054      850
# 0                                     Vauxhall astra  23815041    1,950
# 0                             2012 Audi A5 cabriolet  22462246   12,500
# 0         2009 Citroen Grand Picasso 1.6 diesel VTR+  23660606    1,950
# 0                 2010  Volkswagen Golf DIESEL €4350  23448717    4,350
# 0     2009Ford Fiesta1.4 TDCI Style.Very low mileage  23799200    1,950
# 0                                            Peugeot  23815034    7,250
# 0                                 Toyota d4d 6 speed  23815029    1,800
# 0                  16 vauxhall corsa 1.4 ltd edition  23485820    5,250
# 0                                         Ford focus  23776025      300
# 0                              Mercedes CDI for sale  23815017      650
# 0                             Audi A4 2.0tdi Technik  23392800    4,995
# 0                              14 vauxhall agila 1.0  23478283    3,750
# 0                                08 Mazda 2 for sale  23814997    1,800
# 0              Renault Megane GT Line 1.6 dci 130bhp  23208590   10,450
# 0              MINII SPORT 1.4 AS NEW NCT 09/20 MINT  23814990    3,500
# 0                      VW polo 1.4 diesel bluemotion  23814931    2,500
# 0                                          Vw passat  23814989      950
# ..                                               ...       ...      ...
# 0    161 Mercedes-Benz CLS CLS220 D AMG LINE Premium  23623739   33,000
# 0                                            7seater  22712996    1,400
# 0                                     Audi a6 saloon  23442799    8,500
# 0                                           BMW 320i  23708889    1,990
# 0                      2016 162 Kia Sportage 1.7 EXS  23459619   18,750
# 0   Nissan Note 1.4 N-TEC with SAT NAV and Bluetooth  23634295    4,050
# 0                                2005 Toyota Avensis  23708793      999
# 0                                           GTI 1.8T  23081145    1,750
# 0                       AUDI A6 S-LINE BLACK EDYTION  23708748        1
# 0    Toyota Yaris 00, New NCT, New Batery, Serviced.  23708758      850
# 0                                  Mercedes E220 CDI  23708712    4,950
# 0                          2009 Audi A6 2.0 TDI AUTO  23310119    3,300
# 0                              Honda Fit hybrid 2010  23649297    5,500
# 0                    Honda insight, 2010. 1.3 HYBRID  23661715    5,950
# 0            Vauxhall Insignia Auto 2.o DieselEstate  23708625    2,250
# 0                                 Hyundai i30 estate  23708586    3,500
# 0                                      Audi A4 Avant  23684428    6,200
# 0                                 BMW 520D Automatic  22799724   15,250
# 0                     Mitsubishi Carisma, 2002, 1.6l  23708500      450
# 0                                 Volkswagen Golf 06  23708502    1,500
# 0                           152 BMW Series 5 M sport  22807131   21,800
# 0                                           Mercedes  23105158    1,200
# 0                               Skoda fabia ambiente  23656383    1,250
# 0        * MASSIVE PRICE DROP IF GONE THIS WEEKEND *  23037618    5,100
# 0                                         131 BMW X1  23588020   13,850
# 0                     Volkswagon Golf 1.4 Sport 80BH  23292915    2,300
# 0                                       Audi A4 2009  23486330    4,250
# 0                  Dacia Sandero Stepway Alternative  22232581   11,990
# 0                Renault KADJAR Dynamique NAV Energy  21409366   14,990
# 0             Renault Zoe Dynamique NAV R110 Z.e. 40  22563001   25,590
#
#                                                ad_url car_body_type  \
# 0   https://www.donedeal.ie/cars-for-sale/volkswag...         Coupe
# 0   https://www.donedeal.ie/cars-for-sale/mercedes...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/ford-foc...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/peugeot-...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/volkswag...           MPV
# 0   https://www.donedeal.ie/cars-for-sale/2007-toy...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/2006-nis...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/renault-...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/golf-gti...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/nissan-q...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/nissan-t...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/kia-spor...           SUV
# 0   https://www.donedeal.ie/cars-for-sale/toyota-a...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/vauxhall...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/2012-aud...     Cabriolet
# 0   https://www.donedeal.ie/cars-for-sale/2009-cit...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/2010-vol...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/2009ford...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/peugeot/...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/toyota-d...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/16-vauxh...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/ford-foc...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/mercedes...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/audi-a4-...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/14-vauxh...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/08-mazda...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/renault-...        Estate
# 0   https://www.donedeal.ie/cars-for-sale/minii-sp...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/vw-polo-...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/vw-passa...        Saloon
# ..                                                ...           ...
# 0   https://www.donedeal.ie/cars-for-sale/161-merc...         Coupe
# 0   https://www.donedeal.ie/cars-for-sale/7seater/...   Estate/Jeep
# 0   https://www.donedeal.ie/cars-for-sale/audi-a6-...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/bmw-320i...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/2016-162...           SUV
# 0   https://www.donedeal.ie/cars-for-sale/nissan-n...           MPV
# 0   https://www.donedeal.ie/cars-for-sale/2005-toy...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/gti-1-8t...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/audi-a6-...        Estate
# 0   https://www.donedeal.ie/cars-for-sale/toyota-y...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/mercedes...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/2009-aud...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/honda-fi...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/honda-in...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/vauxhall...        Estate
# 0   https://www.donedeal.ie/cars-for-sale/hyundai-...           MPV
# 0   https://www.donedeal.ie/cars-for-sale/audi-a4-...        Estate
# 0   https://www.donedeal.ie/cars-for-sale/bmw-520d...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/mitsubis...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/volkswag...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/152-bmw-...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/mercedes...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/skoda-fa...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/massive-...
# 0   https://www.donedeal.ie/cars-for-sale/131-bmw-...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/volkswag...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/audi-a4-...        Saloon
# 0   https://www.donedeal.ie/cars-for-sale/dacia-sa...     Hatchback
# 0   https://www.donedeal.ie/cars-for-sale/renault-...           SUV
# 0   https://www.donedeal.ie/cars-for-sale/renault-...     Hatchback
#
#    car_colour car_engine     ...     car_year green_light_verified  \
# 0       Brown  2.0 litre     ...         2015                 True
# 0        Blue  1.8 litre     ...         2007                 True
# 0       White  1.6 litre     ...         2011                 True
# 0        Blue  1.6 litre     ...         2007                False
# 0       Black  1.6 litre     ...         2014                False
# 0        Blue  1.4 litre     ...         2007                False
# 0        Gold  1.2 litre     ...         2006                False
# 0        Blue  1.4 litre     ...         2004                 True
# 0       White  2.0 litre     ...         2015                 True
# 0       Brown  1.5 litre     ...         2007                 True
# 0        Blue  1.6 litre     ...         2007                False
# 0       Black  1.7 litre     ...         2014                 True
# 0      Silver  1.4 litre     ...         2011                False
# 0       White  1.2 litre     ...         2009                False
# 0       White  2.0 litre     ...         2012                False
# 0      Silver  1.6 litre     ...         2009                False
# 0        Grey  1.6 litre     ...         2010                 True
# 0       Black  1.4 litre     ...         2009                False
# 0        Grey  1.6 litre     ...         2013                 True
# 0       Black  2.0 litre     ...         2008                False
# 0         Red  1.4 litre     ...         2016                False
# 0      Silver  1.4 litre     ...         2005                False
# 0        Blue  2.1 litre     ...         2005                False
# 0       White  2.0 litre     ...         2012                False
# 0       White  1.0 litre     ...         2014                False
# 0        Grey  1.4 litre     ...         2008                 True
# 0        Blue  1.6 litre     ...         2015                 True
# 0        Grey  1.4 litre     ...         2009                False
# 0      Silver  1.4 litre     ...         2009                 True
# 0       Brown  1.6 litre     ...         2006                False
# ..        ...        ...     ...          ...                  ...
# 0       Black  2.1 litre     ...         2016                 True
# 0        Grey  2.2 litre     ...         2007                False
# 0        Blue  2.0 litre     ...         2011                False
# 0       Black  2.0 litre     ...         2006                False
# 0         Red  1.7 litre     ...         2016                 True
# 0       Beige  1.4 litre     ...         2010                 True
# 0      Silver  2.0 litre     ...         2005                False
# 0       Black  1.8 litre     ...         2003                 True
# 0         Red  2.0 litre     ...         2015                False
# 0      Silver  1.0 litre     ...         2000                 True
# 0       Black  2.1 litre     ...         2009                False
# 0       Beige  2.0 litre     ...         2009                False
# 0      Silver  1.3 litre     ...         2010                False
# 0      Silver  1.3 litre     ...         2010                False
# 0        Grey  2.0 litre     ...         2013                False
# 0         Red  1.6 litre     ...         2012                False
# 0       White  2.0 litre     ...         2009                 True
# 0       Black  2.0 litre     ...         2014                 True
# 0       Black  1.6 litre     ...         2002                False
# 0       Green  1.4 litre     ...         2006                 True
# 0       Black  2.0 litre     ...         2015                False
# 0      Silver  1.8 litre     ...         2005                 True
# 0        Grey  1.2 litre     ...         2006                False
# 0       Black                ...         1991                False
# 0       Black  2.0 litre     ...         2013                False
# 0        Blue  1.4 litre     ...         2007                 True
# 0        Blue  2.0 litre     ...         2009                 True
# 0         Red  1.5 litre     ...         2017                False
# 0        Gold  1.5 litre     ...         2016                 True
# 0       Black                ...         2019                 True
#
#    seller_county seller_county_town seller_id        seller_name  \
# 0       Limerick               None     45000               Mike
# 0           Cork             Mallow     31572              Jim S
# 0      Tipperary     Tipperary Town   3394285               Ford
# 0       Kilkenny               None     17268               DAVE
# 0         Dublin               None   1305041             Joseph
# 0         Galway               Tuam   3294883             Seller
# 0         Dublin               None   2683024              Karen
# 0         Dublin       South County   3200762           Victoria
# 0           Cork               None    916648              Brian
# 0        Wicklow               None   1619223           Ford7810
# 0      Tipperary    Carrick-on-Suir   1243972             Seller
# 0        Wicklow               Bray     67630            F Doyle
# 0        Kildare               Naas   2303193              gavin
# 0          Laois         PortLaoise    513694             Marius
# 0       Monaghan               None   2662176              Gerry
# 0           Cork          Cork City     31772                Tim
# 0         Offaly               None   2443537            Darragh
# 0           Cork          Cork City     31772                Tim
# 0          Louth            Dundalk    725662                  .
# 0          Meath              Kells   3196505              Shane
# 0        Donegal               None    692261             seller
# 0        Wexford              Gorey      7383            Tractor
# 0         Dublin         South City    254748              Peter
# 0         Tyrone              Omagh    783186     CAR4LESS.CO.UK
# 0        Donegal        Letterkenny   1342656             seller
# 0           Cork         Millstreet    737409   Zsuzsanna Nemeth
# 0      Waterford               None     83279            brendan
# 0           None               None   3259592                Tom
# 0        Kildare          Kilcullen   1386771               Polo
# 0         Dublin               None    649261         Przemyslaw
# ..           ...                ...       ...                ...
# 0         Dublin         North City     72197             Adrian
# 0       Longford     Edgeworthstown    708554              Gints
# 0           Cork     Castletownbere    299744                Dan
# 0           None               None   3252622  Bolaji Animashaun
# 0           Cork          Cork City   2092061         Mark Joyce
# 0         Dublin               None   2485586              Helen
# 0          Meath               None   2948057     Richard Cullen
# 0         Dublin               None   2522804             VeeDub
# 0         Dublin               None    748094               alan
# 0           Cork       Passage West   1290277         Signe noer
# 0         Carlow               None    321437    Richard coleman
# 0      Tipperary               None   2554527             Adrian
# 0         Dublin         North City    206729               ross
# 0         Dublin         North City    206729               ross
# 0         Tyrone              Omagh    547449             Philip
# 0       Limerick      Limerick City   1030943                 ME
# 0        Donegal           Buncrana    544227     Edward Doherty
# 0         Dublin        West County    503717             Ciaran
# 0       Kilkenny               None   2201510      Meike Donohue
# 0           None               None   3305697               John
# 0           Cork          Cork City    473811               S.C.
# 0         Dublin       South County   3318350      Martin O Gara
# 0         Dublin               None    644999    Ovidijus Stonys
# 0        Donegal               None   2254709               AUDI
# 0       Kilkenny         Thomastown    182481               Mick
# 0      Tipperary             Cashel   3179651              Jacob
# 0          Meath              Navan   2097342      Jamie  cullen
# 0           None               None   3275697     kearysmidleton
# 0           None               None   3275697     kearysmidleton
# 0           None               None   3275697     kearysmidleton
#
#    seller_num_ads seller_phone_number          seller_reg_date seller_type
# 0               1                None  2010-06-28 14:20:52.312     PRIVATE
# 0               2                None  2009-09-08 22:43:12.027     PRIVATE
# 0               1                None  2019-12-13 21:40:41.166     PRIVATE
# 0               8                None   2010-10-15 18:39:45.67     PRIVATE
# 0               1                None  2014-12-09 17:10:33.103     PRIVATE
# 0               2                None  2019-08-24 13:46:54.711     PRIVATE
# 0               1                None  2017-07-09 15:45:53.435     PRIVATE
# 0               6                None  2019-05-04 20:49:29.546     PRIVATE
# 0               1                None  2014-03-19 18:18:37.946     PRIVATE
# 0               3                None  2015-06-02 15:38:11.201     PRIVATE
# 0               1                None  2014-10-27 11:54:26.113     PRIVATE
# 0               1                None  2009-11-03 13:41:51.218     PRIVATE
# 0               3                None  2016-06-08 14:51:01.559     PRIVATE
# 0               1                None   2013-02-19 19:30:39.14     PRIVATE
# 0               1                None  2017-06-16 23:38:17.937     PRIVATE
# 0               9                None  2012-02-06 17:58:43.344     PRIVATE
# 0               5                None  2016-10-11 20:49:13.357     PRIVATE
# 0               9                None  2012-02-06 17:58:43.344     PRIVATE
# 0               1                None  2012-11-25 20:20:39.038     PRIVATE
# 0               1                None  2019-04-28 22:07:35.431     PRIVATE
# 0               6                None  2013-08-13 20:24:44.088     PRIVATE
# 0               1                None  2010-03-06 21:21:22.013     PRIVATE
# 0               2                None  2009-10-28 14:00:10.818     PRIVATE
# 0               2                None  2013-05-14 18:07:58.742     PRIVATE
# 0               5                None  2015-01-14 16:40:09.579     PRIVATE
# 0               1                None  2013-09-18 15:14:58.454     PRIVATE
# 0               2                None  2009-06-20 12:16:20.815     PRIVATE
# 0              11                None  2019-07-10 14:41:20.828     PRIVATE
# 0               1                None  2015-02-16 19:55:48.534     PRIVATE
# 0               1                None  2013-07-02 21:30:39.118     PRIVATE
# ..            ...                 ...                      ...         ...
# 0               1                None  2011-07-18 15:09:27.367     PRIVATE
# 0               1                None  2013-08-27 20:08:28.093     PRIVATE
# 0               1                None  2012-08-13 16:50:41.244     PRIVATE
# 0               1                None  2019-07-01 20:30:41.615     PRIVATE
# 0               1                None  2015-12-03 11:54:53.051     PRIVATE
# 0               1                None  2016-11-24 19:38:24.953     PRIVATE
# 0               1                None  2018-06-07 14:58:48.535     PRIVATE
# 0               2                None   2017-01-13 15:48:51.96     PRIVATE
# 0               7                None  2013-09-28 16:54:49.007     PRIVATE
# 0               1                None  2014-11-28 12:09:52.573     PRIVATE
# 0               1                None  2012-08-28 10:01:34.739     PRIVATE
# 0               3                None  2017-02-15 22:57:31.271     PRIVATE
# 0               2                None  2011-08-11 16:50:23.022     PRIVATE
# 0               2                None  2011-08-11 16:50:23.022     PRIVATE
# 0               3                None  2010-07-28 14:50:40.477     PRIVATE
# 0               3                None  2014-06-08 10:34:50.228     PRIVATE
# 0               1                None  2011-03-09 09:05:55.798     PRIVATE
# 0               1                None  2011-01-10 22:23:45.086     PRIVATE
# 0               1                None  2016-03-13 14:32:28.371     PRIVATE
# 0               1                None  2019-09-07 18:33:29.249     PRIVATE
# 0               1                None  2013-01-14 14:33:53.948     PRIVATE
# 0               1                None  2019-09-25 12:04:45.217     PRIVATE
# 0               1                None   2013-06-28 19:47:39.15     PRIVATE
# 0               1                None  2016-04-27 10:36:22.399     PRIVATE
# 0               1                None  2012-05-22 21:41:44.269     PRIVATE
# 0               2                None   2019-04-06 01:56:41.18     PRIVATE
# 0               1                None  2015-12-08 13:01:02.094     PRIVATE
# 0               0                None  2019-07-31 13:58:40.893      DEALER
# 0               0                None  2019-07-31 13:58:40.893      DEALER
# 0               0                None  2019-07-31 13:58:40.893      DEALER
#
# [10007 rows x 30 columns]

# %%
table_location = r"C:\Users\User\Documents\ITB Year 2\Text Analytics and Web Content Mining\Assignments\Assignment 3\github\DoneDeal_Analytics\data\ad_info_table.csv"
ad_info_table.to_csv(table_location)
